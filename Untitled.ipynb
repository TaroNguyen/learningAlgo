# %% [markdown]
# ## Real Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame.from_csv('./data/daily_MSFT.csv')
# Out:
# /Users/apple/anaconda3/envs/DeepLearning/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   if __name__ == '__main__':

# %%
data2 = pd.DataFrame()
prices = data['close']
data2['last returns'] = prices/prices.shift(1) -1

# %%
plt.plot( data2*365)
plt.show()

# %%
np.average(  (data2*365).values[1:]**2)
# Out:
# 30.689974315985655

# %% [markdown]
# ## RNN

# %%
import tensorflow as tf

# %%
rnn_cell =tf.contrib.rnn.RNNCell()

# %%
rnn_cell.weights
# Out:
# []

# %%
0.1/np.sqrt(10) / ( 0.1*np.sqrt(365)/np.sqrt( 5000))
# Out:
# 1.1704114719613055
